# %% [markdown]
# <a href="https://colab.research.google.com/github/jehad8l8/ML/blob/main/L3/Data%20Visualization%20-%20Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt  # import matplotlib library and give it a short name (plt) to use for plotting

# %%
# %matplotlib inline
 # show the plots directly inside Jupyter Notebook output

# %%
import numpy as np  # import numpy library and call it np for short
x = np.linspace(0, 5, 11)  # create 11 numbers between 0 and 5 (start and end included)
y = x ** 2  # square each value in x (so y = x^2)

# %%
x  # display the values stored in
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y  # display the values stored in y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.figure(figsize=(2,2))  # create a new figure with width=2 and height=2 inches
plt.plot(x, y, 'r')  # plot x vs y, 'r' means the line color is red
plt.xlabel('X Axis Title Here')  # set the label for the x-axis
plt.ylabel('Y Axis Title Here')  # set the label for the y-axis
plt.title('String Title Here')  # set the title of the plot
plt.show()  # display the plot

# %%
# plt.subplot(nrows, ncols, plot_number)  # format: rows, columns, which plot number
plt.subplot(1,2,1)  # create a grid with 1 row and 2 columns, select first plot
plt.plot(x, y, 'r--')  # plot red dashed line
plt.subplot(1,2,2)  # select second plot in the same grid
plt.plot(y, x, 'g*-')  # plot green line with star markers

# %%
# Create Figure (empty canvas)
fig = plt.figure()  # create a blank figure object
# Add set of axes to figure
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
# add axes to the figure (position: left, bottom, width, height — values from 0 to 1)
# Plot on that set of axes
axes.plot(x, y, 'b')  # plot x vs y with blue line
axes.set_xlabel('Set X Label')  # set x-axis label (notice methods start with set_)
axes.set_ylabel('Set y Label')  # set y-axis label
axes.set_title('Set Title')     # set plot title
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
# Creates blank canvas
fig = plt.figure()  # create a new empty figure
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
# main axes (big plot area)
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])
# smaller axes inside the figure (like a zoomed/inset plot)
# Larger Figure Axes 1
axes1.plot(x, y, 'b')  # plot x vs y in blue on main axes
axes1.set_xlabel('X_label_axes1')  # set x label for main axes
axes1.set_ylabel('Y_label_axes1')  # set y label for main axes
axes1.set_title('Axes 1 Title')    # set title for main axes
# Insert Figure Axes 2
axes2.plot(y, x, 'r')  # plot y vs x in red on smaller axes
axes2.set_xlabel('X_label_axes2')  # set x label for inset axes
axes2.set_ylabel('Y_label_axes2')  # set y label for inset axes
axes2.set_title('Axes 2 Title')    # set title for inset axes
# Out:
# Text(0.5, 1.0, 'Axes 2 Title')

# %%
# Use similar to plt.figure() but it returns both figure and axes
fig, axes = plt.subplots()  # create figure and axes in one line (tuple unpacking)
# Now use the axes object to add stuff to plot
axes.plot(x, y, 'r')  # plot x vs y with red line
axes.set_xlabel('x')  # set x-axis label
axes.set_ylabel('y')  # set y-axis label
axes.set_title('title')  # set plot title
# Out:
# Text(0.5, 1.0, 'title')

# %%
# Empty canvas of 1 row and 2 columns of subplots
fig, axes = plt.subplots(nrows=1, ncols=2)
# create a figure with 1 row and 2 separate plot areas (axes)

# %%
# Axes is an array (list-like) that contains the two subplot axes
axes  # display the axes objects
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
for ax in axes:  # loop through each subplot (each axes object)
    ax.plot(x, y, 'b')  # plot x vs y in blue on each subplot
    ax.set_xlabel('x')  # set x-axis label
    ax.set_ylabel('y')  # set y-axis label
    ax.set_title('title')  # set title for each subplot
# Display the figure object
fig  # show the full figure with all subplots

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
# create a figure with 1 row and 2 subplots
for ax in axes:  # loop through each subplot
    ax.plot(x, y, 'g')  # plot x vs y in green
    ax.set_xlabel('x')  # set x-axis label
    ax.set_ylabel('y')  # set y-axis label
    ax.set_title('title')  # set title
fig  # display the figure
plt.tight_layout()  # automatically fix spacing so plots don’t overlap

# %%
fig = plt.figure(figsize=(8,4), dpi=100)
# create a figure with width=8 inches and height=4 inches, dpi=100 controls image resolution

# %%
fig, axes = plt.subplots(figsize=(4,2))
# create a figure with size 4x2 inches
axes.plot(x, y, 'r')  # plot x vs y with red line
axes.set_xlabel('x')  # set x-axis label
axes.set_ylabel('y')  # set y-axis label
axes.set_title('title')  # set plot title
# Out:
# Text(0.5, 1.0, 'title')

# %%
fig.savefig("filename.png")  # save the current figure as a PNG image file

# %%
fig.savefig("filename.png", dpi=200)  # save the figure with higher resolution (better quality image)

# %%
ax.set_title("title")  # set the title for this specific axes (plot)
# Out:
# Text(0.5, 1.0, 'title')

# %%
ax.set_xlabel("x")  # set the label for the x-axis
ax.set_ylabel("y")  # set the label for the y-axis
# Out:
# Text(336.49999999999994, 0.5, 'y')

# %%
fig = plt.figure()  # create a new empty figure
ax = fig.add_axes([0,0,1,1])
# add axes that take the full figure area (left, bottom, width, height)
ax.plot(x, x**2, label="x**2")  # plot x^2 and give it a label for legend
ax.plot(x, x**3, label="x**3")  # plot x^3 and give it a label
ax.legend()  # show the legend using the labels we defined

# %%
# Lots of options....
ax.legend(loc=1)  # place legend in upper right corner
ax.legend(loc=2)  # place legend in upper left corner
ax.legend(loc=3)  # place legend in lower left corner
ax.legend(loc=4)  # place legend in lower right corner
# .. many more location options exist
# Most common to choose
ax.legend(loc=0)  # let matplotlib automatically choose the best location
fig  # display the figure

# %%
# MATLAB style line color and style
fig, ax = plt.subplots()  # create figure and axes
ax.plot(x, x**2, 'b.-')  # blue line with dot markers
ax.plot(x, x**3, 'g--')  # green dashed line

# %%
fig, ax = plt.subplots()  # create figure and axes
ax.plot(x, x+1, color="blue", alpha=0.5)
# blue line with 50% transparency (alpha controls opacity)
ax.plot(x, x+2, color="#8B008B")
# line with custom color using hex code (dark magenta)
ax.plot(x, x+3, color="#FF8C00")
# line with custom hex color (orange)

# %%
fig, ax = plt.subplots(figsize=(12,6))
# create a bigger figure (12x6 inches)

# Different line widths
ax.plot(x, x+1, color="red", linewidth=0.25)  # very thin red line
ax.plot(x, x+2, color="red", linewidth=0.50)  # thin red line
ax.plot(x, x+3, color="red", linewidth=1.00)  # normal red line
ax.plot(x, x+4, color="red", linewidth=2.00)  # thicker red line

# Different line styles
ax.plot(x, x+5, color="green", lw=3, linestyle='-')   # solid green line
ax.plot(x, x+6, color="green", lw=3, ls='-.')         # dash-dot green line
ax.plot(x, x+7, color="green", lw=3, ls=':')          # dotted green line

# Custom dash pattern
line, = ax.plot(x, x+8, color="black", lw=1.50)
# store the line object to customize it
line.set_dashes([5, 10, 15, 10])
# custom dash pattern: line length, space, line, space...

# Different marker styles
ax.plot(x, x+9,  color="blue", lw=3, ls='-',  marker='+')  # plus marker
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')  # circle marker
ax.plot(x, x+11, color="blue", lw=3, ls='-',  marker='s')  # square marker
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')  # triangle marker

# Marker size and colors
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
# small circle marker

ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
# medium circle marker

ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o',
        markersize=8, markerfacecolor="red")
# bigger circle with red inside

ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s',
        markersize=8, markerfacecolor="yellow",
        markeredgewidth=3, markeredgecolor="green")
# square marker with yellow fill and green border

# %%
fig, ax = plt.subplots(figsize=(12,6))
# create a bigger figure (12x6 inches)

# Different line widths
ax.plot(x, x+1, color="red", linewidth=0.25)  # very thin red line
ax.plot(x, x+2, color="red", linewidth=0.50)  # thin red line
ax.plot(x, x+3, color="red", linewidth=1.00)  # normal red line
ax.plot(x, x+4, color="red", linewidth=2.00)  # thicker red line

# Different line styles
ax.plot(x, x+5, color="green", lw=3, linestyle='-')   # solid green line
ax.plot(x, x+6, color="green", lw=3, ls='-.')         # dash-dot green line
ax.plot(x, x+7, color="green", lw=3, ls=':')          # dotted green line

# Custom dash pattern
line, = ax.plot(x, x+8, color="black", lw=1.50)
# store the line object to customize it
line.set_dashes([5, 10, 15, 10])
# custom dash pattern: line length, space, line, space...

# Different marker styles
ax.plot(x, x+9,  color="blue", lw=3, ls='-',  marker='+')  # plus marker
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')  # circle marker
ax.plot(x, x+11, color="blue", lw=3, ls='-',  marker='s')  # square marker
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')  # triangle marker

# Marker size and colors
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
# small circle marker

ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
# medium circle marker

ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o',
        markersize=8, markerfacecolor="red")
# bigger circle with red inside

ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s',
        markersize=8, markerfacecolor="yellow",
        markeredgewidth=3, markeredgecolor="green")
# square marker with yellow fill and green border

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
# create a figure with 1 row and 3 subplots (side by side)

axes[0].plot(x, x**2, x, x**3)
# plot two lines on first subplot (x^2 and x^3)
axes[0].set_title("default axes ranges")
# default axis limits

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
# automatically adjust axes to fit the data tightly
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
# manually set y-axis range
axes[2].set_xlim([2, 5])
# manually set x-axis range
axes[2].set_title("custom axes range")
# Out:
# Text(0.5, 1.0, 'custom axes range')

# %%
plt.scatter(x, y)  # create a scatter plot (points instead of lines)

# %%
from random import sample  # import sample function to generate random values
data = sample(range(1, 1000), 100)
# generate 100 random unique numbers between 1 and 999
plt.hist(data)  # create a histogram to show the distribution of the data
# Out:
# (array([10., 10.,  7., 12., 13.,  8., 11., 11.,  5., 13.]),
#  array([  2. , 100.8, 199.6, 298.4, 397.2, 496. , 594.8, 693.6, 792.4,
#         891.2, 990. ]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]
# create 3 datasets with normal distribution
# mean = 0, std = 1, 2, 3 and each has 100 values

# rectangular box plot
plt.boxplot(data, vert=True, patch_artist=True)
# create a boxplot for the datasets
# vert=True makes it vertical
# patch_artist=True fills the boxes with color
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a440465f1d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a43f51fbb00>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x7a43f51bf740>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7a43f50c80b0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7a43f50c8380>,
# ...
#  'means': []}
